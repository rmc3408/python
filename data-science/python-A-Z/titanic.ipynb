# %%
import pandas as pd
import seaborn as sns
titanic = pd.read_csv('titanic.csv')

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
ages = titanic['Age']
ages.shape
type(ages)
# Out:
# (891,)

# %%
ages.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.histplot(ages)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
rich_adult_filter = (titanic["Pclass"] == 1) & (titanic["Age"] > 25)
poor_adult_filter = (titanic["Pclass"] == 3) & (titanic["Age"] > 25)

rich_adult_names = titanic.loc[rich_adult_filter, "Name"] # 144 names
poor_adult_names = titanic.loc[poor_adult_filter, "Name"] # 161 names

# sns.relplot(titanic, x='Survived', y='Age') # all data

rich_poor_adults = titanic[rich_adult_filter | poor_adult_filter]

# Data describe difference between Male and Female in class 1 or class 3.
sns.boxplot(rich_poor_adults, x='Pclass', y='Age', hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
